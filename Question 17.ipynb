# %%
n = 20
even_number_list = []
for i in range(2,n+1,2):
    print(i)
    even_number_list.append(i)
print(even_number_list)

# %%
even_number_list = [i for i in range(2,n+1,2)]
print(even_number_list)

# %%
def generate_even_numbers(n: int) -> int:


    if not isinstance(n, int):
        raise TypeError("Input must be a integer")
    if n <=2:
        raise ValueError("Input must be grater than or equal to 2")
      
     even_number_list = [i for i in range(2,n+1,2)]
     return even_numbers

# main execution 
if __name__ =="__main__":
    n =30
    try:
        result = generate_even_numbers(n)
        print("Even Numbers List :",result)
    except(TypeError,ValueError) as e:
        print("Error :",e)
    except Exception as e:
        print("Error :",e)
